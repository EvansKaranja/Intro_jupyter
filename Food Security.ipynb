# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import sklearn as sk
from math import sqrt
import fiona
import os

# %%
df = pd.read_csv("raw_data/Counties_Food_Security_data.csv")

# %%
df.head()
# Out:
#    Code   County  Severe stunting in children (%)  \
# 0   1.0  Baringo                              9.9
# 1   2.0    Bomet                             15.2
# 2   3.0  Bungoma                             13.6
# 3   4.0    Busia                             10.7
# 4   5.0     Embu                              8.5
#
#    Severe wasting in children (%)  Severe underweight (%)  \
# 0                             4.8                     1.6
# 1                             2.9                     3.6
# 2                             1.8                     0.9
# 3                             0.2                     0.7
# 4                             5.3                     0.4
#
#    Food poverty rate (%)  Poor_Feeding_Score  Borderline_feeding_score  \
# 0                    8.5                 7.0                      21.0
# 1                    6.1                 1.0                       5.0
# 2                    8.8                 1.0                       9.0
# ...

# %%
df.tail()
# Out:
#     Code County  Severe stunting in children (%)  \
# 68   NaN    NaN                              NaN
# 69   NaN    NaN                              NaN
# 70   NaN    NaN                              NaN
# 71   NaN    NaN                              NaN
# 72   NaN    NaN                              NaN
#
#     Severe wasting in children (%)  Severe underweight (%)  \
# 68                             NaN                     NaN
# 69                             NaN                     NaN
# 70                             NaN                     NaN
# 71                             NaN                     NaN
# 72                             NaN                     NaN
#
#     Food poverty rate (%)  Poor_Feeding_Score  Borderline_feeding_score  \
# 68                    NaN                 NaN                       NaN
# 69                    NaN                 NaN                       NaN
# 70                    NaN                 NaN                       NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Code   County  Severe stunting in children (%)  \
# 0    1.0  Baringo                              9.9
# 1    2.0    Bomet                             15.2
# 2    3.0  Bungoma                             13.6
# 3    4.0    Busia                             10.7
# 4    5.0     Embu                              8.5
# ..   ...      ...                              ...
# 68   NaN      NaN                              NaN
# 69   NaN      NaN                              NaN
# 70   NaN      NaN                              NaN
# 71   NaN      NaN                              NaN
# 72   NaN      NaN                              NaN
#
#     Severe wasting in children (%)  Severe underweight (%)  \
# 0                              4.8                     1.6
# 1                              2.9                     3.6
# 2                              1.8                     0.9
# 3                              0.2                     0.7
# ...

# %%
print(df.to_string())
# Out:
#     Code          County  Severe stunting in children (%)  Severe wasting in children (%)  Severe underweight (%)  Food poverty rate (%)  Poor_Feeding_Score  Borderline_feeding_score  Unacceptable_Feeding_Score  Maize_Production(Ton)  Beans_Production(Ton)        TLU  Land Area (Km2)  Arable Land (Km2)  Arable Land (%) Rural_Population Urban_Population Total Population Population_Density/sqKm  Male Literacy  Female Literacy  Overall Literacy  poverty_rate_percentage   GCP_USD  Mean_distance_to_roads  Conflict_cases_per_year  Food_Source_Purchases  Food_Source_Stock  Food_Source_Own_production  Food_source_Gifts  Access_improved Sanitation services  Access to Water  Access to_Unimproved Sanitation Services  Average Rainfall  Evapotransipiration
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 46
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Code                                      47 non-null     float64
#  1   County                                    47 non-null     object
#  2   Severe stunting in children (%)           47 non-null     float64
#  3   Severe wasting in children (%)            47 non-null     float64
#  4   Severe underweight (%)                    47 non-null     float64
#  5   Food poverty rate (%)                     47 non-null     float64
#  6   Poor_Feeding_Score                        47 non-null     float64
#  7   Borderline_feeding_score                  47 non-null     float64
#  8   Unacceptable_Feeding_Score                47 non-null     float64
#  9   Maize_Production(Ton)                     47 non-null     float64
# ...

# %%
df.corr()
# Out:
#                                               Code  \
# Code                                      1.000000
# Severe stunting in children (%)          -0.097123
# Severe wasting in children (%)            0.049092
# Severe underweight (%)                    0.051302
# Food poverty rate (%)                     0.153372
# Poor_Feeding_Score                        0.145656
# Borderline_feeding_score                  0.282500
# Unacceptable_Feeding_Score                0.226725
# Maize_Production(Ton)                     0.108210
# Beans_Production(Ton)                    -0.223564
# TLU                                       0.163918
# Land Area (Km2)                           0.167958
# Arable Land (Km2)                        -0.113001
# Arable Land (%)                          -0.103746
# Male Literacy                            -0.168234
# Female Literacy                          -0.142314
# Overall Literacy                         -0.154315
# ...

# %%
fp = "spatial_data/Counties_food_security.shp"

# %%
sp_data = gpd.read_file(fp)

# %%
type(sp_data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
sp_data.head()
# Out:
#        COUNTY  Code  Severe_stu  Severe_was  Severe_und  Food_pover  \
# 0     Turkana  23.0         7.8         4.7        15.9        52.7
# 1    Marsabit  10.0        16.1        11.5        11.5        23.8
# 2     Mandera   9.0        18.5         5.8         6.2        38.9
# 3       Wajir   8.0         8.3         1.8         2.6        10.5
# 4  West Pokot  24.0        14.8         7.8         7.1        26.2
#
#    Poor_Feedi  Borderline  Unacceptab  Maize_Prod  ...  Food_Sou_1  \
# 0        19.0        24.0        43.0      3741.0  ...        13.8
# 1         2.0         3.0        15.0       347.0  ...        11.5
# 2         3.0        11.0        12.0         0.0  ...         5.2
# 3         3.0        10.0         6.0      1034.0  ...        18.8
# 4         3.0        22.0        25.0     61840.0  ...        14.8
#
#    Food_Sou_2  Food_sou_3  Access_imp  Access_to_  Access_to1  Average_Ra  \
# 0         7.0        16.0        31.9        33.9        74.9  359.476373
# ...
